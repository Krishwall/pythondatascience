# %% [markdown]
# pillow
# - image
# - image processing
#     - image resize
#     - image rotate
#     - image crop
#     - image flip
#     - image enhance
#     - image draw
# - image save

# %%
from PIL import Image,ImageDraw, ImageEnhance

# %%
img_path=r"C:\Users\KRISH\OneDrive\Images\Tony.jpeg"
im2_path=r"C:\Users\KRISH\Downloads\twin peak wall.jpg"
im1=Image.open(img_path)
im2=Image.open(im2_path)

# %%
print(im1)
print(im2)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x1BB999A3B30>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225 at 0x1BB99B4DB80>

# %%
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
im1.show()

# %%
# load image from url
import requests

def load_image(url):
    return Image.open(requests.get(url,stream=True).raw)

# %%
url="https://printler.com/en/poster/162551/"
im3=load_image(url)   
im3
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[18], line 2
#       1 url="https://printler.com/en/poster/162551/"
# ----> 2 im3=load_image(url)
#       3 im3
#
# Cell In[12], line 5, in load_image(url)
#       4 def load_image(url):
# ----> 5     return Image.open(requests.get(url,stream=True).raw)
#
# File c:\Users\KRISH\miniconda3\Lib\site-packages\PIL\Image.py:3339, in open(fp, mode, formats)
#    3337     warnings.warn(message)
#    3338 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3339 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x000001BB9D34C040>

# %%
im3.save('batman.png')

# %%
im2.transpose(Image.FLIP_TOP_BOTTOM)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
im2.size
print(im2.height,im2.width,im2.mode)
# Out:
# 225 225 RGB

# %%
im2.resize((225,225))
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
